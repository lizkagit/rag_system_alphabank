# %%
import pandas as pd

# %%
df = pd.read_csv('input_data/websites.csv')

# %%
df.head(10)
# Out:
#    web_id                                                url  kind  \
# 0       1                               https://alfabank.ru/  html
# 1       2                        https://alfabank.ru/a-club/  html
# 2       3               https://alfabank.ru/a-club/ultimate/  html
# 3       4                 https://alfabank.ru/actions/rules/  html
# 4       5                    https://alfabank.ru/alfafuture/  html
# 5       6  https://alfabank.ru/alfafuture/blog/alfabank-l...  html
# 6       7  https://alfabank.ru/alfafuture/blog/alfatim-na...  html
# 7       8  https://alfabank.ru/alfafuture/blog/kak-dostic...  html
# 8       9  https://alfabank.ru/alfafuture/blog/obuchenie-...  html
# 9      10  https://alfabank.ru/alfafuture/blog/otkryli-la...  html
#
#                                                title  \
# 0  Альфа-Банк - кредитные и дебетовые карты, кред...
# 1                      А-Клуб. Деньги имеют значение
# 2                      А-Клуб. Деньги имеют значение
# ...

# %%
df_questions = pd.read_csv('input_data/questions_clean.csv')
df_questions.head(10)
# Out:
#    q_id                                              query
# 0     1                                        Номер счета
# 1     2                              Где узнать бик и счёт
# 2     3  Мне не приходят коды для подтверждения данной ...
# 3     4  Оформила рассрочку ,но уведомлений никаких не ...
# 4     5  Здравствуйте, когда смогу пользоваться кредитн...
# 5     6                  По истории платеж не отображается
# 6     7  Здравствуйте, в рп. Нахабино отделение банка н...
# 7     8                            Узнать зарплатный счет
# 8     9  Подскажите, где я могу увидеть дату начала пол...
# 9    10                                    Не приходит смс

# %%
# Нужно будет разделить по знаку \n
df['text'][0]
# Out:
# 'Рассчитайте выгоду\nРасчёт калькулятора предварительный. Персональные условия вы сможете узнать после оформления заявки\nПолучайте больше с Альфа-Банком\nСервисы\nКурсы валют\nВалюта | Покупка | Продажа |\n|---|---|---|\nДоллар США (USD) | 77 | 80,4 |\nЕвро (EUR) | 92 | 94,5 |\nКитайский юань (CNY) | 11,15 | 12,15 |\nБольше валют\nИнформация о курсах обмена иностранных валют является справочной и может меняться в течение дня. Точную информацию о курсах можно узнать в интернет-банке. Список отделений доступен по ссылке'

# %%
df_submission = pd.read_csv('input_data/sample_submission.csv')

# %%
df_submission
# Out:
#       q_id                        web_list
# 0        1     [935, 687, 963, 1893, 1885]
# 1        2    [1660, 1882, 1040, 1090, 64]
# 2        3      [1246, 698, 465, 757, 307]
# 3        4      [366, 1625, 461, 279, 678]
# 4        5    [898, 589, 1162, 1889, 1181]
# ...    ...                             ...
# 6972  6973        [19, 700, 830, 1207, 24]
# 6973  6974    [664, 1135, 779, 1023, 1818]
# 6974  6975       [1162, 81, 369, 205, 664]
# 6975  6976    [1726, 1499, 1074, 873, 219]
# 6976  6977  [1521, 1562, 1799, 1456, 1883]
#
# [6977 rows x 2 columns]
